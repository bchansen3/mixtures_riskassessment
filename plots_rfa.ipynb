# %% [markdown]
# ## This file reproduces some the plots included in the *_Utilizing Human Exposure and Biomonitoring Data to Improve the Application of New Approach Methods in Fit-For-Purpose Mixture Assessment_* proposal.

# %% [markdown]
# ### To make a bimodal distribution

# %%
library(tidyverse)
library(ggplot2)
set.seed(4)

par(mfrow=c(2,1))

bimod <- c(rnorm(1000, 0, 1), rnorm(500, -4, 1))
  ggplot(mapping = aes(bimod)) +geom_density(color ="blue",fill ="lightblue")+
      theme_classic()+
      theme(axis.title.x=element_blank(),
        axis.text.x=element_blank(),
        axis.ticks.x=element_blank(),
        axis.title.y=element_blank(),
        axis.text.y=element_blank(),
        axis.ticks.y=element_blank())

onemod <- c(rnorm(1500, 0, 1))
    ggplot(mapping = aes(onemod)) +geom_density(color ="blue",fill ="lightblue")+
      theme_classic()+
      theme(axis.title.x=element_blank(),
        axis.text.x=element_blank(),
        axis.ticks.x=element_blank(),
        axis.title.y=element_blank(),
        axis.text.y=element_blank(),
        axis.ticks.y=element_blank())
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# plot without title
# plot without title

# %%
par(mfrow=c(2,1))

set.seed(4)

samp_bimod <- sample(bimod, size=500, replace=T)

samp_onemod <- sample(onemod, size=500, replace=T)


  ggplot(mapping = aes(samp_bimod)) +geom_histogram(color ="blue",fill ="lightblue")+
      theme_classic()+
      theme(axis.title.x=element_blank(),
        axis.text.x=element_blank(),
        axis.ticks.x=element_blank(),
        axis.title.y=element_blank(),
        axis.text.y=element_blank(),
        axis.ticks.y=element_blank()) 

onemod <- c(rnorm(1500, 0, 1))
  ggplot(mapping = aes(samp_onemod)) +geom_histogram(color ="blue",fill ="lightblue")+
      theme_classic()+
      theme(axis.title.x=element_blank(),
        axis.text.x=element_blank(),
        axis.ticks.x=element_blank(),
        axis.title.y=element_blank(),
        axis.text.y=element_blank(),
        axis.ticks.y=element_blank())
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %% [markdown]
# ### To make a example fit lines

# %%
mixtab <- data.frame(
    dose = c(1:12),
    mix = c(0,0,15,50,100,100,100,100,100,100, 100,100),
    low = c(0,0,0, 8,10,80,100,100,100,100,100,100),
    med = c(0,0,0,0,0,4,15,50,80,100, 100,100),
    high = c(0,0,0,0,0,0,2,8,20,60,100,100))




  ggplot(mixtab, aes (x=dose)) + 
  geom_smooth(aes(y=mix), color ="red",se=F)+
  geom_smooth(aes(y=low), color="blue",se=F)+
  geom_smooth(aes(y=med), color = "blue",se=F)+  
  geom_smooth(aes(y=high),color = "blue",se=F)+
       theme_classic()+
      scale_y_continuous(limits =c(0,100))+
      scale_x_continuous(limits =c(0,13))+
      theme(axis.title.x=element_blank(),
        axis.text.x=element_blank(),
        axis.ticks.x=element_blank(),
        axis.title.y=element_blank())
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message:
# “Removed 21 rows containing missing values (geom_smooth).”
# Warning message:
# “Removed 44 rows containing missing values (geom_smooth).”
# Warning message:
# “Removed 35 rows containing missing values (geom_smooth).”
# Warning message:
# “Removed 39 rows containing missing values (geom_smooth).”
# plot without title
